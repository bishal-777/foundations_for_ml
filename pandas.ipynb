# %%
import pandas as pd

# %%
pd.DataFrame({'Phy':[90,80],'Chem':[70,40]})
# Out:
#    Phy  Chem
# 0   90    70
# 1   80    40

# %%
pd.DataFrame({'Sem 2':['OOP','ECM','EDC','Chemistry','DL','Math II'],'Sem 3':['Data Science','CG','TOC','MAth III','Microprocessor','English']})
# Out:
#        Sem 2           Sem 3
# 0        OOP    Data Science
# 1        ECM              CG
# 2        EDC             TOC
# 3  Chemistry        MAth III
# 4         DL  Microprocessor
# 5    Math II         English

# %%
pd.Series([5,10,15])
# Out:
# 0     5
# 1    10
# 2    15
# dtype: int64

# %%
pd.Series([5,10,15],index=['a','b','c'],name='Score')
# Out:
# a     5
# b    10
# c    15
# Name: Score, dtype: int64

# %%
covid=pd.read_csv("datasets/country_wise_covid.csv")

# %%
covid.shape
# Out:
# (187, 15)

# %%
covid.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
covid['Country/Region'][4]
# Out:
# 'Angola'

# %%
covid.iloc[2]
# Out:
# Country/Region            Algeria
# Confirmed                   27973
# Deaths                       1163
# Recovered                   18837
# Active                       7973
# New cases                     616
# New deaths                      8
# New recovered                 749
# Deaths / 100 Cases           4.16
# Recovered / 100 Cases       67.34
# Deaths / 100 Recovered       6.17
# Confirmed last week         23691
# 1 week change                4282
# 1 week % increase           18.07
# WHO Region                 Africa
# Name: 2, dtype: object

# %%
covid.iloc[1:6,0]
# Out:
# 1                Albania
# 2                Algeria
# 3                Andorra
# 4                 Angola
# 5    Antigua and Barbuda
# Name: Country/Region, dtype: object

# %%
covid.loc[3,'Country/Region']
# Out:
# 'Andorra'

# %%
covid.set_index("New deaths")
# Out:
#                 Country/Region  Confirmed  Deaths  Recovered  Active  \
# New deaths
# 10                 Afghanistan      36263    1269      25198    9796
# 6                      Albania       4880     144       2745    1991
# 8                      Algeria      27973    1163      18837    7973
# 0                      Andorra        907      52        803      52
# 1                       Angola        950      41        242     667
# ...                        ...        ...     ...        ...     ...
# 2           West Bank and Gaza      10621      78       3752    6791
# 0               Western Sahara         10       1          8       1
# 4                        Yemen       1691     483        833     375
# 1                       Zambia       4552     140       2815    1597
# 2                     Zimbabwe       2704      36        542    2126
#
#             New cases  New recovered  Deaths / 100 Cases  \
# New deaths
# ...
